# %% [markdown]
# # Corrections exp-draft.ipynb

# %% [markdown]
# ## Fonction Quadratique
#
# ### quad_simple
# - Pas de zigzags
#
# ### quad_comparison
# - Simple : pas de zigzags
# - Momentum : devrait être plus lisse et direct, part en vrille
# - Nesterov : devrait être encore plus lisse que Momentum mais tourne
# - Adam : OK, trajectoire directe, la plus rapide
#
# ### quad_convergence
# - Axe y : soucis avec l'échelle logarithmique ?
# - On dirait que l'échelle est inversée, Simple est le plus rapide et Adam le plus lent ?
# - Aucune stabilisation des courbes
#
# ## Fonctions simples g et h
#
# ### g_comparison
# - Courbes de niveau centrées en (0, 0) OK
# - Pas de trajectoire des algorithmes, une seule itération
#
# ### g_convergence
# - Aucune trajectoire, graphe vide
# - 1 itération ?
#
# ### h_comparison
# - Courbes de niveau complexes OK
# - Les algorithmes ne convergent pas vers un même minimum local
# - Adam part complètement à l'autre bout du graphe ?
#
# ### h_convergence
# - Adam rapide
# - Simple et Nesterov continuent hors du graphe sans diminuer
# - Momentum invisible ?
# - Aucun min local en commun ?
#
# ## Rosenbrock
#
# ### rosenbrock_adam
# - Tout semble OK
#
# ### rosenbrock_comparison
# - Seulement la trajectoire d'Adam
#
# ### rosenbrock_convergence
# - Echelle semble faux pour l'axe y
# - Momentum et Nesterov identiques ?
# - Adam plus rapide
# - Simple plus lente
#
# ## Booth
#
# ### booth_comparison
# - Courbes de niveau OK
# - Trajectoires pas du tout directes pour Adam, Nesterov et Momentum
# - Grosses différences dans les trajectoires
#
# ### booth_convergence
# - Encore une fois peut-on vérifier les axes surtout le y ?
# - Ordre : Nesterov meilleur, puis Momentum, Adam, Simple
# - Différences très marquées
#
# ## Beale
#
# ### beale_comparison
# - Pas de courbes de niveau près de l'origine
# - Minimum OK en (3, 0.5)
# - Les 4 algos sont à 2001 iter. Adam est la seule qui descent plus vite vers x = 0,8
# - Pas de légende pour les axes ?
#
# ### beale_convergence
# - Simple a une convergence lente
# - Adam moyenne
# - Nesterov et Momentum plus rapides et se chevauchent
#
# ## Himmelblau
#
# ### himmelblau_comparison
# - Paysage complexe et point de départ OK
# - Convergence complètement fausse pour les algos
# - Adam très lent, Simple très rapide...
#
# ### himmelblau_convergence
# - Simple et Nesterov très rapides
# - Momentum et Adam lentes
#
# ## Ackley
# - Tout reste bloqué dans des minimums d'après mes outputs
#
# ### ackley_adam
# - Paysage OK
# - Aucune trajectoire visible malgré 241 iter
#
# ### ackley_comparison
# - Aucune trajectoire des algorithmes
#
# ### ackley_convergence
# - Tout est faux, mêmes commentaires
#
# ## Dual vs Numérique
#
# ### ackley_gradient_comparison
# - Aucun changement visuel OK
#
# #### TABLEAU RÉCAPITULATIF DES PERFORMANCES
#
#    Fonction      Simple    Momentum    Nesterov     Adam
# Quadratique    74 itér.   101 itér.    92 itér. XX itér.
#  Rosenbrock 2000+ itér. 2000+ itér. 2000+ itér. XX itér.
#       Booth    XX itér.    XX itér.    XX itér. XX itér.
#       Beale    XX itér.    XX itér.    XX itér. XX itér.
#  Himmelblau    XX itér.    XX itér.    XX itér. XX itér.
#
# Note : Remplacer les XX par les vraies valeurs après exécution
#
# ## Cas d'échecs
#
# ### echec1_lr
# - Aucune trajectoire visible
#
# ### echec1_convergence
# - α=0.5 ne descend pas et n'oscille pas
# - Le reste OK
#
# ### echec2_lr
# - Trajectoires OK
#
# ### echec2_convergence
# - Trajectoires OK mais soucis avec l'axe y pour l'échelle ?
#
# ### echec3_minima
# - Pas de trajectoires, juste les points dans les minima ? Normal ?
#
# ### echec3_convergence
# - Trajectoires plates et très hautes, tout faux
#
# ### echec4_momentum
# - Semble faux... oscillations extrêmes et virages pas lisses avec des angles
#
# ### echec4_convergence
# - Faux, descente 0.5 pas lisse
# - Beaucoup de vagues pour les 4 trajectoires
#
# ### echec5_zigzags
# - Momentum pas lisse...
#
# ### echec5_convergence
# - Semble vraiment faux
